# %% [markdown]
# #Tarea : "Pandas 2"
#
# Andrea Espindola Macias y Desmond Anthony Ryan
#
# 10/10/2022

# %% [markdown]
# <font color='red'>La tarea consiste en realizar un análisis exploratorio (completo) de su base de datos como lo muestra el siguiente ejemplo.
#
# 1. Es necesario documentar todo su código.
# 2. Es necesario que escriba sus conclusiones.</font>
#
# En el github: https://github.com/ZesarGal/AED- encontrará la base de datos y el repositorio de este notebook.

# %%
import pandas as pd

# %%
shoedata = pd.read_csv("shoes_dataset.csv")

# %% [markdown]
# ##Metodos .head() y .tail()
#
# .head() = ver los primeros renglones
#
# .tail() = ver los ultimos

# %%
shoedata.head(10)
# Out:
#   Order Date      Brand                                    Sneaker   Sale  \
# 0    1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1,525
# 1    1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1,661
# 2    1/15/18  Off White                  Air Force 1 Low Off White    615
# 3    1/15/18  Off White                  Air Force 1 Low Off White    625
# 4    1/15/18  Off White                       Air Max 97 Off White    750
# 5    1/15/18  Off White                       Air Max 97 Off White    620
# 6    1/15/18  Off White                       Air Presto Off White  1,150
# 7    1/15/18  Off White                     Air VaporMax Off White    805
# 8    1/15/18  Off White                       Blazer Mid Off White    660
# 9    1/15/18  Off White                       Blazer Mid Off White    690
#
#    Retail  Profit  ProfitPercent   Buyer Region
# 0     190    1335     702.631579       New York
# 1     190    1471     774.210526          Texas
# ...

# %% [markdown]
# En esta base de datos encontramos toda la información acerca de los pedidos de zapatos Off-WHite. En primer lugar, tenemos la fecha de la orden y la marca que claramente es igual en todos los pedidos. En seguida enocntramos el apartado "sneakers" que es el modelo de calzado. Igualmente, tenemos otro apartado "sale" que indica la cantidad por la cual el zapato se vendió y otro de "retail" que es el precio del zapato de fabrica o lo que pagó la tienda por el. Por ende, también tenemos que tener un apartado llamado "profit" el cual indica la ganancia que se generó en la venta de cada zapato, al igual que el porcentaje de esta ganancia. Por último tenemos el apartado de "region" en el cual se indica el lugar en el que se hizo el pedido del calzado.

# %%
shoedata.tail(10)
# Out:
#     Order Date      Brand                                 Sneaker   Sale  \
# 102    1/21/18  Off White                    Air Max 97 Off White    700
# 103    1/21/18  Off White                    Air Max 97 Off White    700
# 104    1/21/18  Off White                    Air Presto Off White  1,086
# 105    1/21/18  Off White                    Air Presto Off White  1,185
# 106    1/21/18  Off White                    Air Presto Off White  1,285
# 107    1/21/18  Off White                  Air VaporMax Off White    790
# 108    1/21/18  Off White                  Air VaporMax Off White    870
# 109    1/21/18  Off White                    Blazer Mid Off White    615
# 110    1/21/18  Off White  React Hyperdunk 2017 Flyknit Off White    415
# 111    1/21/18  Off White                      Zoom Fly Off White    535
#
#      Retail  Profit  ProfitPercent Buyer Region
# 102     190     510     268.421053      Florida
# 103     190     510     268.421053   California
# ...

# %% [markdown]
# ##Metodo .info()
#
# informacion basica de la base de datos

# %%
shoedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     112 non-null    object
#  1   Brand          112 non-null    object
#  2   Sneaker        112 non-null    object
#  3   Sale           112 non-null    object
#  4   Retail         112 non-null    int64
#  5   Profit         112 non-null    int64
#  6   ProfitPercent  112 non-null    float64
#  7   Buyer Region   112 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 7.1+ KB

# %% [markdown]
# ##Metodo .shape
#
# Vista de matriz

# %%
shoedata.shape
# Out:
# (112, 8)

# %% [markdown]
# ##Metodo .describe()
#
# *summary* estadístico-descriptivo de los atributos numéricos

# %%
shoedata.describe()
# Out:
#            Retail       Profit  ProfitPercent
# count  112.000000   112.000000     112.000000
# mean   181.428571   637.419643     363.244919
# std     31.303718   363.969770     207.973384
# min    130.000000   160.000000      80.000000
# 25%    160.000000   419.750000     220.294737
# 50%    190.000000   530.000000     294.243421
# 75%    190.000000   810.750000     506.718750
# max    250.000000  1535.000000     807.894737

# %% [markdown]
# ##Seleccion de Datos

# %% [markdown]
# .columns = muestra columnas de la base de datos.
#
# . [[  ]] = pasar de serie a un dataframe

# %%
shoedata.columns
# Out:
# Index(['Order Date', 'Brand', 'Sneaker', 'Sale', 'Retail', 'Profit',
#        'ProfitPercent', 'Buyer Region'],
#       dtype='object')

# %%
shoedata["Brand"]
# Out:
# 0      Off White
# 1      Off White
# 2      Off White
# 3      Off White
# 4      Off White
#          ...
# 107    Off White
# 108    Off White
# 109    Off White
# 110    Off White
# 111    Off White
# Name: Brand, Length: 112, dtype: object

# %%
type(shoedata["Brand"])
# Out:
# pandas.core.series.Series

# %%
shoedata[["Brand"]]
# Out:
#          Brand
# 0    Off White
# 1    Off White
# 2    Off White
# 3    Off White
# 4    Off White
# ..         ...
# 107  Off White
# 108  Off White
# 109  Off White
# 110  Off White
# 111  Off White
#
# [112 rows x 1 columns]

# %%
shoedata[["Order Date", "Brand", "Sneaker", "Sale", "Retail"]]
# Out:
#     Order Date      Brand                                    Sneaker   Sale  \
# 0      1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1,525
# 1      1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1,661
# 2      1/15/18  Off White                  Air Force 1 Low Off White    615
# 3      1/15/18  Off White                  Air Force 1 Low Off White    625
# 4      1/15/18  Off White                       Air Max 97 Off White    750
# ..         ...        ...                                        ...    ...
# 107    1/21/18  Off White                     Air VaporMax Off White    790
# 108    1/21/18  Off White                     Air VaporMax Off White    870
# 109    1/21/18  Off White                       Blazer Mid Off White    615
# 110    1/21/18  Off White     React Hyperdunk 2017 Flyknit Off White    415
# 111    1/21/18  Off White                         Zoom Fly Off White    535
#
#      Retail
# 0       190
# 1       190
# 2       170
# ...

# %% [markdown]
# ## Seleción usando renglones: Métodos `.loc` y `.iloc`

# %% [markdown]
# - `.loc` localiza renglones por nombre
# - `.ìloc` localiza renglones por índices.

# %%
shoedata.head(10)
# Out:
#   Order Date      Brand                                    Sneaker   Sale  \
# 0    1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1,525
# 1    1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1,661
# 2    1/15/18  Off White                  Air Force 1 Low Off White    615
# 3    1/15/18  Off White                  Air Force 1 Low Off White    625
# 4    1/15/18  Off White                       Air Max 97 Off White    750
# 5    1/15/18  Off White                       Air Max 97 Off White    620
# 6    1/15/18  Off White                       Air Presto Off White  1,150
# 7    1/15/18  Off White                     Air VaporMax Off White    805
# 8    1/15/18  Off White                       Blazer Mid Off White    660
# 9    1/15/18  Off White                       Blazer Mid Off White    690
#
#    Retail  Profit  ProfitPercent   Buyer Region
# 0     190    1335     702.631579       New York
# 1     190    1471     774.210526          Texas
# ...

# %%
shoedata.loc[5]
# Out:
# Order Date                    1/15/18
# Brand                       Off White
# Sneaker          Air Max 97 Off White
# Sale                              620
# Retail                            190
# Profit                            430
# ProfitPercent              226.315789
# Buyer Region            Massachusetts
# Name: 5, dtype: object

# %%
shoedata.iloc[10:20][["Order Date", "Brand", "Sneaker"]]
# Out:
#    Order Date      Brand                                    Sneaker
# 10    1/15/18  Off White     React Hyperdunk 2017 Flyknit Off White
# 11    1/15/18  Off White     React Hyperdunk 2017 Flyknit Off White
# 12    1/15/18  Off White     React Hyperdunk 2017 Flyknit Off White
# 13    1/15/18  Off White     React Hyperdunk 2017 Flyknit Off White
# 14    1/15/18  Off White                         Zoom Fly Off White
# 15    1/16/18  Off White  Air Jordan 1 Retro High Off White Chicago
# 16    1/16/18  Off White  Air Jordan 1 Retro High Off White Chicago
# 17    1/16/18  Off White                       Air Max 97 Off White
# 18    1/16/18  Off White                       Air Max 97 Off White
# 19    1/16/18  Off White                       Air Presto Off White

# %% [markdown]
# ## Selección de datos sujetas a condiciones

# %% [markdown]
# 1. Queremos ver cuantas ventas, han tenido un "Profit" , (ganancia), mayor o igual a 500.

# %%
shoedata[shoedata ["Profit"] >= 500]
# Out:
#     Order Date      Brand                                    Sneaker   Sale  \
# 0      1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1,525
# 1      1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1,661
# 4      1/15/18  Off White                       Air Max 97 Off White    750
# 6      1/15/18  Off White                       Air Presto Off White  1,150
# 7      1/15/18  Off White                     Air VaporMax Off White    805
# ..         ...        ...                                        ...    ...
# 104    1/21/18  Off White                       Air Presto Off White  1,086
# 105    1/21/18  Off White                       Air Presto Off White  1,185
# 106    1/21/18  Off White                       Air Presto Off White  1,285
# 107    1/21/18  Off White                     Air VaporMax Off White    790
# 108    1/21/18  Off White                     Air VaporMax Off White    870
#
#      Retail  Profit  ProfitPercent  Buyer Region
# ...

# %%
profitmayor500 = shoedata[ shoedata["Profit"] >= 500]
profitmayor500
# Out:
#     Order Date      Brand                                    Sneaker   Sale  \
# 0      1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1,525
# 1      1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1,661
# 4      1/15/18  Off White                       Air Max 97 Off White    750
# 6      1/15/18  Off White                       Air Presto Off White  1,150
# 7      1/15/18  Off White                     Air VaporMax Off White    805
# ..         ...        ...                                        ...    ...
# 104    1/21/18  Off White                       Air Presto Off White  1,086
# 105    1/21/18  Off White                       Air Presto Off White  1,185
# 106    1/21/18  Off White                       Air Presto Off White  1,285
# 107    1/21/18  Off White                     Air VaporMax Off White    790
# 108    1/21/18  Off White                     Air VaporMax Off White    870
#
#      Retail  Profit  ProfitPercent  Buyer Region
# ...

# %%
profitmayor500[["Order Date", "Sale", "Brand","Sneaker"]]
# Out:
#     Order Date   Sale      Brand                                    Sneaker
# 0      1/15/18  1,525  Off White  Air Jordan 1 Retro High Off White Chicago
# 1      1/15/18  1,661  Off White  Air Jordan 1 Retro High Off White Chicago
# 4      1/15/18    750  Off White                       Air Max 97 Off White
# 6      1/15/18  1,150  Off White                       Air Presto Off White
# 7      1/15/18    805  Off White                     Air VaporMax Off White
# ..         ...    ...        ...                                        ...
# 104    1/21/18  1,086  Off White                       Air Presto Off White
# 105    1/21/18  1,185  Off White                       Air Presto Off White
# 106    1/21/18  1,285  Off White                       Air Presto Off White
# 107    1/21/18    790  Off White                     Air VaporMax Off White
# 108    1/21/18    870  Off White                     Air VaporMax Off White
#
# [65 rows x 4 columns]

# %% [markdown]
# 2. Queremos ver aquellos pedidos en los que se obtuvo una venta mayor o igual a 1000 y menor a 3500.

# %%
shoedata['Sale']= shoedata['Sale'].apply(str).str.replace(',','').astype(float)

shoedata
# Out:
#     Order Date      Brand                                    Sneaker    Sale  \
# 0      1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1525.0
# 1      1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1661.0
# 2      1/15/18  Off White                  Air Force 1 Low Off White   615.0
# 3      1/15/18  Off White                  Air Force 1 Low Off White   625.0
# 4      1/15/18  Off White                       Air Max 97 Off White   750.0
# ..         ...        ...                                        ...     ...
# 107    1/21/18  Off White                     Air VaporMax Off White   790.0
# 108    1/21/18  Off White                     Air VaporMax Off White   870.0
# 109    1/21/18  Off White                       Blazer Mid Off White   615.0
# 110    1/21/18  Off White     React Hyperdunk 2017 Flyknit Off White   415.0
# 111    1/21/18  Off White                         Zoom Fly Off White   535.0
#
# ...

# %%
shoedata[(shoedata["Sale"]>1000) & (shoedata["Sale"]<3500)]
# Out:
#     Order Date      Brand                                    Sneaker    Sale  \
# 0      1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1525.0
# 1      1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1661.0
# 6      1/15/18  Off White                       Air Presto Off White  1150.0
# 15     1/16/18  Off White  Air Jordan 1 Retro High Off White Chicago  1725.0
# 16     1/16/18  Off White  Air Jordan 1 Retro High Off White Chicago  1555.0
# 19     1/16/18  Off White                       Air Presto Off White  1150.0
# 27     1/17/18  Off White  Air Jordan 1 Retro High Off White Chicago  1700.0
# 28     1/17/18  Off White  Air Jordan 1 Retro High Off White Chicago  1403.0
# 29     1/17/18  Off White  Air Jordan 1 Retro High Off White Chicago  1510.0
# 35     1/17/18  Off White                       Air Presto Off White  1080.0
# 44     1/18/18  Off White  Air Jordan 1 Retro High Off White Chicago  1550.0
# ...

# %% [markdown]
# ##Metodo .groupby()
#
#     Agrupamiento de Datos

# %%
shoedata.groupby("Brand").mean()
# Out:
#                  Sale      Retail      Profit  ProfitPercent
# Brand
# Off White  818.848214  181.428571  637.419643     363.244919

# %% [markdown]
# ##Metodo .sort_values

# %%
shoedata.groupby("Brand")[["Sale"]].mean().sort_values(['Sale'], ascending = False).head(10)
# Out:
#                  Sale
# Brand
# Off White  818.848214

# %% [markdown]
# ##Preprocesamiento de Datos

# %%
shoedata.isnull().sum()
# Out:
# Order Date       0
# Brand            0
# Sneaker          0
# Sale             0
# Retail           0
# Profit           0
# ProfitPercent    0
# Buyer Region     0
# dtype: int64

# %% [markdown]
# (no hay valores nulos en esta base de datos)

# %% [markdown]
# ##Datos NaN: Metodo .dropna()

# %%
shoedata2 = shoedata.dropna()
shoedata2.head()
# Out:
#   Order Date      Brand                                    Sneaker    Sale  \
# 0    1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1525.0
# 1    1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1661.0
# 2    1/15/18  Off White                  Air Force 1 Low Off White   615.0
# 3    1/15/18  Off White                  Air Force 1 Low Off White   625.0
# 4    1/15/18  Off White                       Air Max 97 Off White   750.0
#
#    Retail  Profit  ProfitPercent Buyer Region
# 0     190    1335     702.631579     New York
# 1     190    1471     774.210526        Texas
# 2     170     445     261.764706   California
# 3     170     455     267.647059        Texas
# 4     190     560     294.736842     Michigan

# %% [markdown]
# ##Crear un Indice:

# %% [markdown]
# Crearemos una funcion para clasificar las ventas en: "buenas" o "malas", de acuerdo al "profit" que se obtuvo de la venta.

# %%
def sales(profit):
  if profit > 1000:
      return "buena"
  elif profit < 1000:
    return "mala"

sales
# Out:
# <function __main__.sales(profit)>

# %% [markdown]
# ##Graficas:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(shoedata['Sale'])

# %%
shoedata.head()
# Out:
#   Order Date      Brand                                    Sneaker    Sale  \
# 0    1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1525.0
# 1    1/15/18  Off White  Air Jordan 1 Retro High Off White Chicago  1661.0
# 2    1/15/18  Off White                  Air Force 1 Low Off White   615.0
# 3    1/15/18  Off White                  Air Force 1 Low Off White   625.0
# 4    1/15/18  Off White                       Air Max 97 Off White   750.0
#
#    Retail  Profit  ProfitPercent Buyer Region
# 0     190    1335     702.631579     New York
# 1     190    1471     774.210526        Texas
# 2     170     445     261.764706   California
# 3     170     455     267.647059        Texas
# 4     190     560     294.736842     Michigan

# %%
shoedata.describe()
# Out:
#               Sale      Retail       Profit  ProfitPercent
# count   112.000000  112.000000   112.000000     112.000000
# mean    818.848214  181.428571   637.419643     363.244919
# std     362.718097   31.303718   363.969770     207.973384
# min     360.000000  130.000000   160.000000      80.000000
# 25%     610.000000  160.000000   419.750000     220.294737
# 50%     695.000000  190.000000   530.000000     294.243421
# 75%     970.750000  190.000000   810.750000     506.718750
# max    1725.000000  250.000000  1535.000000     807.894737

# %%
sns.histplot(shoedata['Sale'], bins = 100)

# %% [markdown]
# #Conclusiones Generales
#
# DESPUES DE REALIZAR ESTE ANALISIS DESCRIPTIVO DE NUESTRA BASE DE DATOS  RELACIONADO CON LA VENTA DE UNA TIENDA DE SNEAKERS, NOTAMOS QUE FUE DE GRAN AYUDA PARA COMPRENDER DE MANERA MAS PRACTICA Y SENCILLA LOS DATOS QUE PRESENTA LA BASE DE DATOS. ESTE ANALISIS NOS PERMITE ABSTRAER LA INFORMACIÓN Y ESTAR CONSCIENTES DEL VALOR QUE TIENE EL SABER INTERPRETARLA CORRECTAMENTE.AL SER NOSOTROS MUY VISUALES, LAS GRAFICAS NOS AYUDAN A PLASMAR LOS DATOS DE MANERA QUE NOS PERMITE ANALIZARLA, INTERPRETARLA Y SACAR CONCLUSIONES DE ELLA DE MANERA MAS SENCILLA.
